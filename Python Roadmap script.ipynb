# %% [markdown]
# ## Data Types

# %%
#create a variable with integer value.
a=100
print("The type of variable having value", a, " is ", type(a))

#create a variable with float value.
b=10.2345
print("The type of variable having value", b, " is ", type(b))

#create a variable with complex value.
c=100+3j
print("The type of variable having value", c, " is ", type(c))
# Out:
# The type of variable having value 100  is  <class 'int'>
# The type of variable having value 10.2345  is  <class 'float'>
# The type of variable having value (100+3j)  is  <class 'complex'>

# %%
import requests

url = "https://api.mockaroo.com/api/generate.csv"
params = {
    'key': 'YOUR_API_KEY',
    'count': 10,
    'fields': '[{"name":"name","type":"First Name"},{"name":"email","type":"Email Address"},{"name":"age","type":"Number","min":18,"max":99}]'
}

response = requests.get(url, params=params)
data = response.text
print(data)
# Out:
# name,email,age
# Shana,smacconchie0@hostgator.com,24.32
# Chloe,cpaula1@yandex.ru,26.51
# Elfrida,eghirardi2@ow.ly,41.61
# Melosa,mhannah3@usa.gov,34.99
# Byrann,barman4@state.tx.us,81.5
# Zenia,zsongest5@illinois.edu,71.19
# Newton,nshone6@theglobeandmail.com,90.49
# Granger,gstanworth7@sfgate.com,77.71
# Patrizia,pprandin8@reference.com,79.92
# Micki,mjozsa9@nih.gov,61.36

# %%
import requests
import csv

url = "https://api.mockaroo.com/api/generate.csv"
params = {
    'key': 'YOUR_API_KEY',
    'count': 10,
    'fields': '[{"name":"name","type":"First Name"},{"name":"email","type":"Email Address"},{"name":"age","type":"Number","min":18,"max":99}]'
}

response = requests.get(url, params=params)
data = response.text

# Specify the file path where you want to save the CSV
file_path = "generated_data.csv"

# Write the data to the CSV file
with open(file_path, mode='w', newline='') as file:
    file.write(data)

print(f"CSV data has been saved to {file_path}")
# Out:
# CSV data has been saved to generated_data.csv

# %%
import requests
import csv

# Replace 'YOUR_API_KEY' with your actual Mockaroo API key
api_key = 'YOUR_API_KEY'

# Specify the base URL for the Mockaroo API
base_url = 'https://api.mockaroo.com/api/generate.csv'

# Define the data fields and their types
data_fields = [

{'name': 'Address Line 2', 'type': 'AddressLine2'},
{'name': 'Airport Code', 'type': 'AirportCode'},
{'name': 'Airport Continent', 'type': 'AirportContinent'},
{'name': 'Username', 'type': 'Username'},
{'name': 'Words', 'type': 'Words'}
    
# {"name":"AddressLine2","type":"AddressLine2"},
# {"name":"AirportCode","type":"AirportCode"},
# {"name":"AirportContinent","type":"AirportContinent"},
# {"name":"AirportCountryCode","type":"AirportCountryCode"}
#     {"name": "Airport Elevation (Feet)", "type": "AirportElevationFeet"},
#     {"name": "Airport GPS Code", "type": "AirportGPSCode"},
#     {"name": "Airport Latitude", "type": "AirportLatitude"},
#     {"name": "Airport Longitude", "type": "AirportLongitude"},
#     {"name": "Airport Municipality", "type": "AirportMunicipality"},
#     {"name": "Airport Name", "type": "AirportName"},
#     {"name": "Airport Region Code", "type": "AirportRegionCode"},
#     {"name": "Animal Common Name", "type": "AnimalCommonName"},
#     {"name": "Animal Scientific Name", "type": "AnimalScientificName"},
#     {"name": "App Bundle ID", "type": "AppBundleID"},
#     {"name": "App Name", "type": "AppName"},
#     {"name": "App Version", "type": "AppVersion"},
#     {"name": "Avatar", "type": "Avatar"},
#     {"name": "Base64 Image URL", "type": "Base64ImageURL"},
#     {"name": "Binomial Distribution", "type": "BinomialDistribution"},
#     {"name": "Bitcoin Address", "type": "BitcoinAddress"},
#     {"name": "Blank", "type": "Blank"},
#     {"name": "Boolean", "type": "Boolean"},
#     {"name": "Buzzword", "type": "Buzzword"},
#     {"name": "Car Make", "type": "CarMake"},
#     {"name": "Car Model", "type": "CarModel"},
#     {"name": "Car Model Year", "type": "CarModelYear"},
#     {"name": "Car VIN", "type": "CarVIN"},
#     {"name": "Catch Phrase", "type": "CatchPhrase"},
#     {"name": "Character Sequence", "type": "CharacterSequence"},
#     {"name": "City", "type": "City"},
#     {"name": "Color", "type": "Color"},
#     {"name": "Company Name", "type": "CompanyName"},
#     {"name": "Construction Heavy Equipment", "type": "ConstructionHeavyEquipment"},
#     {"name": "Construction Material", "type": "ConstructionMaterial"},
#     {"name": "Construction Role", "type": "ConstructionRole"},
#     {"name": "Construction Standard Cost Code", "type": "ConstructionStandardCostCode"},
#     {"name": "Construction Subcontract Category", "type": "ConstructionSubcontractCategory"},
#     {"name": "Construction Trade", "type": "ConstructionTrade"},
#     {"name": "Country", "type": "Country"},
#     {"name": "Country Code", "type": "CountryCode"},
#     {"name": "Credit Card #", "type": "CreditCard#"},
#     {"name": "Credit Card Type", "type": "CreditCardType"},
#     {"name": "Currency", "type": "Currency"},
#     {"name": "Currency Code", "type": "CurrencyCode"},
#     {"name": "Custom List", "type": "CustomList"},
#     {"name": "Dataset Column", "type": "DatasetColumn"},
#     {"name": "Datetime", "type": "Datetime"},
#     {"name": "Department (Corporate)", "type": "Department(Corporate)"},
#     {"name": "Department (Retail)", "type": "Department(Retail)"},
#     {"name": "Digit Sequence", "type": "DigitSequence"},
#     {"name": "Domain Name", "type": "DomainName"},
#     {"name": "Drug Company", "type": "DrugCompany"},
#     {"name": "Drug Name (Brand)", "type": "DrugName(Brand)"},
#     {"name": "Drug Name (Generic)", "type": "DrugName(Generic)"},
#     {"name": "Dummy Image URL", "type": "DummyImageURL"},
#     {"name": "DUNS Number", "type": "DUNSNumber"},
#     {"name": "EIN", "type": "EIN"},
#     {"name": "Email Address", "type": "EmailAddress"},
#     {"name": "Encrypt", "type": "Encrypt"},
#     {"name": "Ethereum Address", "type": "EthereumAddress"},
#     {"name": "Exponential Distribution", "type": "ExponentialDistribution"},
#     {"name": "Fake Company Name", "type": "FakeCompanyName"},
#     {"name": "Family Name (Chinese)", "type": "FamilyName(Chinese)"},
#     {"name": "FDA NDC Code", "type": "FDANDCCode"},
#     {"name": "File Name", "type": "FileName"},
#     {"name": "First Name", "type": "FirstName"},
#     {"name": "First Name (European)", "type": "FirstName(European)"},
#     {"name": "First Name (Female)", "type": "FirstName(Female)"},
#     {"name": "First Name (Male)", "type": "FirstName(Male)"},
#     {"name": "Formula", "type": "Formula"},
#     {"name": "Frequency", "type": "Frequency"},
#     {"name": "Full Name", "type": "FullName"},
#     {"name": "Gender", "type": "Gender"},
#     {"name": "Gender (abbrev)", "type": "Gender(abbrev)"},
#     {"name": "Gender (Binary)", "type": "Gender(Binary)"},
#     {"name": "Gender (Facebook)", "type": "Gender(Facebook)"},
#     {"name": "Geometric Distribution", "type": "GeometricDistribution"},
#     {"name": "Given Name (Chinese)", "type": "GivenName(Chinese)"},
#     {"name": "GUID", "type": "GUID"},
#     {"name": "Hex Color", "type": "HexColor"},
#     {"name": "IBAN", "type": "IBAN"},
#     {"name": "ICD10 Diagnosis Code", "type": "ICD10DiagnosisCode"},
#     {"name": "ICD10 Dx Desc (Long)", "type": "ICD10DxDesc(Long)"},
#     {"name": "ICD10 Dx Desc (Short)", "type": "ICD10DxDesc(Short)"},
#     {"name": "ICD10 Proc Desc (Long)", "type": "ICD10ProcDesc(Long)"},
#     {"name": "ICD10 Proc Desc (Short)", "type": "ICD10ProcDesc(Short)"},
#     {"name": "ICD10 Procedure Code", "type": "ICD10ProcedureCode"},
#     {"name": "ICD9 Diagnosis Code", "type": "ICD9DiagnosisCode"},
#     {"name": "ICD9 Dx Desc (Long)", "type": "ICD9DxDesc(Long)"},
#     {"name": "ICD9 Dx Desc (Short)", "type": "ICD9DxDesc(Short)"},
#     {"name": "ICD9 Proc Desc (Long)", "type": "ICD9ProcDesc(Long)"},
#     {"name": "ICD9 Proc Desc (Short)", "type": "ICD9ProcDesc(Short)"},
#     {"name": "ICD9 Procedure Code", "type": "ICD9ProcedureCode"},
#     {"name": "IP Address v4", "type": "IPAddressv4"},
#     {"name": "IP Address v4 CIDR", "type": "IPAddressv4CIDR"},
#     {"name": "IP Address v6", "type": "IPAddressv6"},
#     {"name": "IP Address v6 CIDR", "type": "IPAddressv6CIDR"},
#     {"name": "ISBN", "type": "ISBN"},
#     {"name": "Job Title", "type": "JobTitle"},
#     {"name": "JSON Array", "type": "JSONArray"},
#     {"name": "Language", "type": "Language"},
#     {"name": "Last Name", "type": "LastName"},
#     {"name": "Latitude", "type": "Latitude"},
#     {"name": "LinkedIn Skill", "type": "LinkedInSkill"},
#     {"name": "Longitude", "type": "Longitude"},
#     {"name": "MAC Address", "type": "MACAddress"},
#     {"name": "MD5", "type": "MD5"},
#     {"name": "MIME Type", "type": "MIMEType"},
#     {"name": "Money", "type": "Money"},
#     {"name": "MongoDB ObjectID", "type": "MongoDBObjectID"},
#     {"name": "Movie Genres", "type": "MovieGenres"},
#     {"name": "Movie Title", "type": "MovieTitle"},
#     {"name": "Nato Phonetic", "type": "NatoPhonetic"},
#     {"name": "Naughty String", "type": "NaughtyString"},
#     {"name": "NHS Number", "type": "NHSNumber"},
#     {"name": "Normal Distribution", "type": "NormalDistribution"},
#     {"name": "Number", "type": "Number"},
#     {"name": "Paragraphs", "type": "Paragraphs"},
#     {"name": "Password", "type": "Password"},
#     {"name": "Password Hash", "type": "PasswordHash"},
#     {"name": "Phone", "type": "Phone"},
#     {"name": "Plant Common Name", "type": "PlantCommonName"},
#     {"name": "Plant Family", "type": "PlantFamily"},
#     {"name": "Plant Scientific Name", "type": "PlantScientificName"},
#     {"name": "Poisson Distribution", "type": "PoissonDistribution"},
#     {"name": "Postal Code", "type": "PostalCode"},
#     {"name": "Product (Grocery)", "type": "Product(Grocery)"},
#     {"name": "Race", "type": "Race"},
#     {"name": "Regular Expression", "type": "RegularExpression"},
#     {"name": "Repeating Element", "type": "RepeatingElement"},
#     {"name": "Row Number", "type": "RowNumber"},
#     {"name": "Scenario", "type": "Scenario"},
#     {"name": "Sentences", "type": "Sentences"},
#     {"name": "Sequence", "type": "Sequence"},
#     {"name": "SHA1", "type": "SHA1"},
#     {"name": "SHA256", "type": "SHA256"},
#     {"name": "Shirt Size", "type": "ShirtSize"},
#     {"name": "Short Hex Color", "type": "ShortHexColor"},
#     {"name": "Slogan", "type": "Slogan"},
#     {"name": "SQL Expression", "type": "SQLExpression"},
#     {"name": "SSN", "type": "SSN"},
#     {"name": "State", "type": "State"},
#     {"name": "State (abbrev)", "type": "State(abbrev)"},
#     {"name": "Stock Industry", "type": "StockIndustry"},
#     {"name": "Stock Market", "type": "StockMarket"},
#     {"name": "Stock Market Cap", "type": "StockMarketCap"},
#     {"name": "Stock Name", "type": "StockName"},
#     {"name": "Stock Sector", "type": "StockSector"},
#     {"name": "Stock Symbol", "type": "StockSymbol"},
#     {"name": "Street Address", "type": "StreetAddress"},
#     {"name": "Street Name", "type": "StreetName"},
#     {"name": "Street Number", "type": "StreetNumber"},
#     {"name": "Street Suffix", "type": "StreetSuffix"},
#     {"name": "Suffix", "type": "Suffix"},
#     {"name": "Template", "type": "Template"},
#     {"name": "Tezos Account", "type": "TezosAccount"},
#     {"name": "Tezos Block", "type": "TezosBlock"},
#     {"name": "Tezos Contract", "type": "TezosContract"},
#     {"name": "Tezos Operation", "type": "TezosOperation"},
#     {"name": "Tezos Signature", "type": "TezosSignature"},
#     {"name": "Time", "type": "Time"},
#     {"name": "Time Zone", "type": "TimeZone"},
#     {"name": "Title", "type": "Title"},
#     {"name": "Top Level Domain", "type": "TopLevelDomain"},
#     {"name": "ULID", "type": "ULID"},
#     {"name": "University", "type": "University"},
#     {"name": "URL", "type": "URL"},
#     {"name": "User Agent", "type": "UserAgent"},
#     {"name": "Username", "type": "Username"},
#     {"name": "Words", "type": "Words"},

    # Add more fields as needed
]

# Specify the count for each field
count = 10

# Create and write the CSV file
with open('mockaroo_data.csv', mode='w', newline='') as file:
    writer = csv.writer(file)

    # Write the header row with field names
    header_row = [field['name'] for field in data_fields]
    writer.writerow(header_row)

    # Loop through each data field
    for field in data_fields:
        # Make API request for the field
        params = {'key': api_key, 'count': count, 'fields': [field]}
        response = requests.get(base_url, params=params)

        # Write the data rows to the CSV file
        data_rows = response.text.strip().split('\n')
        for row in data_rows:
            writer.writerow(row.split(','))

print('Data has been successfully written to mockaroo_data.csv')
# Out:
# Data has been successfully written to mockaroo_data.csv

# %%
import re

data = """
Address Line 2
Airport Code
Airport Continent
Username
Words
"""

# Split the data into a list of items
items = [item.strip() for item in data.split("\n") if item.strip()]

# Generate the JSON format
output = []
for item in items:
    formatted_item = {"name": item, "type": re.sub(r'\W+', '', item)}
    output.append(formatted_item)

# Print the result
for item in output:
    print(item)
# Out:
# {'name': 'Address Line 2', 'type': 'AddressLine2'}
# {'name': 'Airport Code', 'type': 'AirportCode'}
# {'name': 'Airport Continent', 'type': 'AirportContinent'}
# {'name': 'Username', 'type': 'Username'}
# {'name': 'Words', 'type': 'Words'}

# %%
import json

# List of items
items = [
    'Address Line 2', 'Airport Code', 'Airport Continent', 'Airport Country Code',
    'Airport Elevation (Feet)', 'Airport GPS Code', 'Airport Latitude', 'Airport Longitude',
    'Airport Municipality', 'Airport Name', 'Airport Region Code', 'Animal Common Name',
    'Animal Scientific Name', 'App Bundle ID', 'App Name', 'App Version', 'Avatar',
    'Base64 Image URL', 'Binomial Distribution', 'Bitcoin Address', 'Blank', 'Boolean',
    'Buzzword', 'Car Make', 'Car Model', 'Car Model Year', 'Car VIN', 'Catch Phrase',
    'Character Sequence', 'City', 'Color', 'Company Name', 'Construction Heavy Equipment',
    'Construction Material', 'Construction Role', 'Construction Standard Cost Code',
    'Construction Subcontract Category', 'Construction Trade', 'Country', 'Country Code',
    'Credit Card #', 'Credit Card Type', 'Currency', 'Currency Code', 'Custom List',
    'Dataset Column', 'Datetime', 'Department (Corporate)', 'Department (Retail)',
    'Digit Sequence', 'Domain Name', 'Drug Company', 'Drug Name (Brand)', 'Drug Name (Generic)',
    'Dummy Image URL', 'DUNS Number', 'EIN', 'Email Address', 'Encrypt', 'Ethereum Address',
    'Exponential Distribution', 'Fake Company Name', 'Family Name (Chinese)', 'FDA NDC Code',
    'File Name', 'First Name', 'First Name (European)', 'First Name (Female)', 'First Name (Male)',
    'Formula', 'Frequency', 'Full Name', 'Gender', 'Gender (abbrev)', 'Gender (Binary)',
    'Gender (Facebook)', 'Geometric Distribution', 'Given Name (Chinese)', 'GUID', 'Hex Color',
    'IBAN', 'ICD10 Diagnosis Code', 'ICD10 Dx Desc (Long)', 'ICD10 Dx Desc (Short)',
    'ICD10 Proc Desc (Long)', 'ICD10 Proc Desc (Short)', 'ICD10 Procedure Code',
    'ICD9 Diagnosis Code', 'ICD9 Dx Desc (Long)', 'ICD9 Dx Desc (Short)', 'ICD9 Proc Desc (Long)',
    'ICD9 Proc Desc (Short)', 'ICD9 Procedure Code', 'IP Address v4', 'IP Address v4 CIDR',
    'IP Address v6', 'IP Address v6 CIDR', 'ISBN', 'Job Title', 'JSON Array', 'Language',
    'Last Name', 'Latitude', 'LinkedIn Skill', 'Longitude', 'MAC Address', 'MD5', 'MIME Type',
    'Money', 'MongoDB ObjectID', 'Movie Genres', 'Movie Title', 'Nato Phonetic', 'Naughty String',
    'NHS Number', 'Normal Distribution', 'Number', 'Paragraphs', 'Password', 'Password Hash',
    'Phone', 'Plant Common Name', 'Plant Family', 'Plant Scientific Name', 'Poisson Distribution',
    'Postal Code', 'Product (Grocery)', 'Race', 'Regular Expression', 'Repeating Element',
    'Row Number', 'Scenario', 'Sentences', 'Sequence', 'SHA1', 'SHA256', 'Shirt Size', 'Short Hex Color',
    'Slogan', 'SQL Expression', 'SSN', 'State', 'State (abbrev)', 'Stock Industry', 'Stock Market',
    'Stock Market Cap', 'Stock Name', 'Stock Sector', 'Stock Symbol', 'Street Address', 'Street Name',
    'Street Number', 'Street Suffix', 'Suffix', 'Template', 'Tezos Account', 'Tezos Block',
    'Tezos Contract', 'Tezos Operation', 'Tezos Signature', 'Time', 'Time Zone', 'Title',
    'Top Level Domain', 'ULID', 'University', 'URL', 'User Agent', 'Username', 'Words'
]

# Convert items to the desired format
formatted_data = [{'name': item, 'type': ''.join(word.capitalize() for word in item.split() if word.isalnum())} for item in items]

# Save the result to a JSON file
output_file_path = 'formatted_data.json'

with open(output_file_path, 'w') as json_file:
    json.dump(formatted_data, json_file, indent=2)

print(f"Formatted data saved to {output_file_path}")
# Out:
# Formatted data saved to formatted_data.json

# %%
import requests
import json
import csv

# Mockaroo API endpoint
api_url = "https://api.mockaroo.com/api/generate.csv"

# Mockaroo API key
api_key = "YOUR_API_KEY"  # Replace with your actual API key

# Load formatted data from JSON file
json_file_path = 'formatted_data.json'
with open(json_file_path, 'r') as json_file:
    formatted_data = json.load(json_file)

# Specify the output CSV file path
output_csv_path = 'mockaroo_output.csv'

# Make API requests for each item in formatted_data
for item in formatted_data:
    params = {
        'key': api_key,
        'count': 1000,  # Number of rows
        'fields': [item],
        'format': 'csv'
    }

    response = requests.get(api_url, params=params)

    # Write the CSV data to the output file
    with open(output_csv_path, 'a', newline='', encoding='utf-8') as csv_file:
        csv_writer = csv.writer(csv_file)
        
        # Write header only if the file is empty
        if csv_file.tell() == 0:
            csv_writer.writerow(response.text.strip().split('\n')[0].split(','))

        # Write the data rows
        csv_writer.writerows(response.text.strip().split('\n')[1:])

print(f"Output saved to {output_csv_path}")
# Out:
# Output saved to mockaroo_output.csv

# %%
import pandas as pd
df = pd.read_csv('Mockaroo_Full.csv')

# %%
df
# Out:
#     Address Line 2 Airport Code Airport Continent Airport Country Code  \
# 0         Suite 78          DOR                AF                   BF
# 1         Apt 1616          LAJ                SA                   BR
# 2         Suite 70          DDM                OC                   PG
# 3         Apt 1592            0                SA                   BR
# 4         Suite 40          IKP                OC                   AU
# ..             ...          ...               ...                  ...
# 994   PO Box 26317          WND                OC                   AU
# 995       Suite 75          FAF               NaN                   US
# 996   PO Box 61933          BOF               NaN                   US
# 997      9th Floor          GNZ                AF                   BW
# 998      6th Floor          PTX                SA                   CO
#
#      Airport Elevation (Feet) Airport GPS Code  Airport Latitude  \
# ...

# %%
series = pd.Series(df)
# Check dtype
print(series.dtype)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1988\2533715018.py in ?()
# ----> 1 series = pd.Series(df)
#       2 # Check dtype
#       3 print(series.dtype)
#
# ~\anaconda3\Lib\site-packages\pandas\core\series.py in ?(self, data, index, dtype, name, copy, fastpath)
#     471                 data = data.reindex(index, copy=copy)
#     472                 copy = False
#     473                 data = data._mgr
#     474         elif is_dict_like(data):
# --> 475             data, index = self._init_dict(data, index, dtype)
#     476             dtype = None
#     477             copy = False
#     478         elif isinstance(data, (SingleBlockManager, SingleArrayManager)):
#
# ~\anaconda3\Lib\site-packages\pandas\core\series.py in ?(self, data, index, dtype)
#     545         keys: Index | tuple
#     546
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 170 columns):
#  #    Column                             Dtype
# ---   ------                             -----
#  0    Address Line 2                     object
#  1    Airport Code                       object
#  2    Airport Continent                  object
#  3    Airport Country Code               object
#  4    Airport Elevation (Feet)           float64
#  5    Airport GPS Code                   object
#  6    Airport Latitude                   float64
#  7    Airport Longitude                  float64
#  8    Airport Municipality               object
#  9    Airport Name                       object
#  10   Airport Region Code                object
#  11   Animal Common Name                 object
#  12   Animal Scientific Name             object
#  13   App Bundle ID                      object
#  14   App Name                           object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Columns: 170 entries, Address Line 2 to Words
# dtypes: bool(1), float64(16), int64(10), object(143)
# memory usage: 1.3+ MB

# %%
df.info
# Out:
# <bound method DataFrame.info of     Address Line 2 Airport Code Airport Continent Airport Country Code  \
# 0         Suite 78          DOR                AF                   BF
# 1         Apt 1616          LAJ                SA                   BR
# 2         Suite 70          DDM                OC                   PG
# 3         Apt 1592            0                SA                   BR
# 4         Suite 40          IKP                OC                   AU
# ..             ...          ...               ...                  ...
# 994   PO Box 26317          WND                OC                   AU
# 995       Suite 75          FAF               NaN                   US
# 996   PO Box 61933          BOF               NaN                   US
# 997      9th Floor          GNZ                AF                   BW
# 998      6th Floor          PTX                SA                   CO
#
#      Airport Elevation (Feet) Airport GPS Code  Airport Latitude  \
# ...

# %%
import io

# Rest of your code

buffer = io.StringIO()
df.info(buf=buffer)

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Columns: 170 entries, Address Line 2 to Words
# dtypes: bool(1), float64(16), int64(10), object(143)
# memory usage: 12.7 MB

# %%
df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Columns: 170 entries, Address Line 2 to Words
# dtypes: bool(1), float64(16), int64(10), object(143)
# memory usage: 1.3+ MB

# %%
df.info(show_counts=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Columns: 170 entries, Address Line 2 to Words
# dtypes: bool(1), float64(16), int64(10), object(143)
# memory usage: 1.3+ MB

# %%
df.memory_usage()
# Out:
# Index                    132
# Address Line 2          7992
# Airport Code            7992
# Airport Continent       7992
# Airport Country Code    7992
#                         ...
# University              7992
# URL                     7992
# User Agent              7992
# Username                7992
# Words                   7992
# Length: 171, dtype: int64

# %%
df.isnull().sum()
# Out:
# Address Line 2                0
# Airport Code                  0
# Airport Continent           305
# Airport Country Code          1
# Airport Elevation (Feet)     41
#                            ...
# University                    0
# URL                           0
# User Agent                    0
# Username                      0
# Words                         0
# Length: 170, dtype: int64

# %%
# Set display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Now, print the result
print(df.isnull().sum())
# Out:
# Address Line 2                         0
# Airport Code                           0
# Airport Continent                    305
# Airport Country Code                   1
# Airport Elevation (Feet)              41
# Airport GPS Code                      58
# Airport Latitude                     999
# Airport Longitude                    999
# Airport Municipality                  89
# Airport Name                           0
# Airport Region Code                    0
# Animal Common Name                     0
# Animal Scientific Name                 0
# App Bundle ID                          0
# App Name                               0
# App Version                            0
# Avatar                                 0
# Base64 Image URL                       0
# Binomial Distribution                  0
# Bitcoin Address                        0
# Blank                                999
# Boolean                                0
# Buzzword                               0
# ...

# %%
# Set display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Check for null counts in each column
null_counts = df.isnull().sum()

# Exclude columns with zero null counts
non_zero_null_counts = null_counts[null_counts > 0]

# Display only those columns with non-zero null counts
print(non_zero_null_counts)
# Out:
# Airport Continent           305
# Airport Country Code          1
# Airport Elevation (Feet)     41
# Airport GPS Code             58
# Airport Latitude            999
# Airport Longitude           999
# Airport Municipality         89
# Blank                       999
# Character Sequence          999
# Custom List                 999
# Digit Sequence              999
# Drug Company                  1
# Formula                     999
# Naughty String               34
# Postal Code                 513
# Regular Expression          999
# SQL Expression              999
# State                       829
# State (abbrev)              829
# Stock Industry              214
# Stock Market Cap            152
# Stock Sector                214
# Template                    999
# dtype: int64

# %%
# Reset display options
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')

# %%
import random

# Numeric Types
integer_number = random.randint(1, 100)
float_number = random.uniform(1.0, 100.0)
complex_number = complex(random.randint(1, 10), random.randint(1, 10))

# Sequence Types
string_type = ''.join(random.choice('abcdefghijklmnopqrstuvwxyz') for _ in range(10))
list_type = [random.randint(1, 10) for _ in range(5)]
tuple_type = tuple(random.randint(1, 10) for _ in range(5))
range_type = range(5)

# Set Type
set_type = {random.randint(1, 10) for _ in range(5)}

# Mapping Type
dictionary_type = {f'key_{i}': random.randint(1, 10) for i in range(5)}

# Boolean Type
boolean_type = random.choice([True, False])

# Binary Types
bytes_type = bytes([random.randint(0, 255) for _ in range(5)])
bytearray_type = bytearray([random.randint(0, 255) for _ in range(5)])

# None Type
none_type = None

# Custom or User-Defined Type
class CustomType:
    def __init__(self, value):
        self.value = value

custom_object = CustomType("Custom Value")

# Printing the types
print("Integer Type:", type(integer_number))
print("Float Type:", type(float_number))
print("Complex Type:", type(complex_number))

print("\nString Type:", type(string_type))
print("List Type:", type(list_type))
print("Tuple Type:", type(tuple_type))
print("Range Type:", type(range_type))

print("\nSet Type:", type(set_type))

print("\nDictionary Type:", type(dictionary_type))

print("\nBoolean Type:", type(boolean_type))

print("\nBytes Type:", type(bytes_type))
print("Bytearray Type:", type(bytearray_type))

print("\nNone Type:", type(none_type))

print("\nCustom Type:", type(custom_object))
# Out:
#   Cell In[60], line 59
#     Integer Type
#             ^
# SyntaxError: invalid syntax

# %%
dictionary_type = {f'key_{i}': random.randint(1, 10) for i in range(5)}
dictionary_type
# Out:
# {'key_0': 4, 'key_1': 3, 'key_2': 7, 'key_3': 6, 'key_4': 7}
